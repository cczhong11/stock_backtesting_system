# %% [markdown]
# # SMA

# %%
import pandas as pd
import numpy as np
from datetime import datetime,timedelta
from jy_strategy import Strategy,SMA,MACD,Param,Kalman,HP,Linear_Model
from matplotlib import pylab
from jy_center import Center_Param, Center
# %matplotlib inline
from matplotlib import pylab
pylab.rcParams['figure.figsize'] = (8, 6)
C_param = Center_Param()# 初始化参数
C_param.start_date='2010-01-01'
C_param.end_date = '2015-12-30'
C = Center(C_param)   # 实例化交易中心变量

df = pd.read_csv("600005.XSHG.csv") #导入测试数据

# %%
p=Param([20],15,15)
C.choose_strategy(SMA("a", df,p))
C.run_test()
C.print_result()
C.print_money()
C.print_trade_log_pic()
C.print_plot_filter()
# Out:
# real date:2009-12-31
# money:1218697.5100000007
# cangwei:0
# roi:0.2186975100000007
# alpha:-0.182120648785
# beta:1.18982408121
# algorithem volatility: 4.08435562371
# bench volatility: 3.22398130464
# sharpe ratio: 0.243687825077
# max drawdown: 0.49886530056054845
# win ratio:0.24421052631578946
# transfer times:34

# %%
C.print_result()
C.print_money()
C.print_trade_log_pic()
C.print_plot_filter()
# Out:
# money:1000000
# cangwei:0
# roi:0.0
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-6-5555304203e0> in <module>()
# ----> 1 C.print_result()
#       2 C.print_money()
#       3 C.print_trade_log_pic()
#       4 C.print_plot_filter()
#
# E:\Coding\python\my_bishe\jy_center.py in print_result(self)
#     413         print("cangwei:"+str(self.cangwei))
#     414         print("roi:"+str(self.calculate_roi()))
# --> 415         print("alpha:"+str(self.calculate_alpha()))
#     416         print("beta:"+str(self.calculate_beta()))
#     417         print("algorithem volatility: "+str(self.calcualte_volatility(1)))
#
# E:\Coding\python\my_bishe\jy_center.py in calculate_alpha(self)
#     274     def calculate_alpha(self):
#     275         '''calculate alpha'''
# --> 276         N = 250/len(self.daily_profit)
#     277         if self.daily_profit[-1]+1>0:
#     278             Rp = (abs(1+self.daily_profit[-1]))**(N)
#
# ZeroDivisionError: division by zero
